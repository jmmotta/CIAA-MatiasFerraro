# %% [markdown]
# <a href="https://colab.research.google.com/github/jmmotta/CIAA-MatiasFerraro/blob/master/bds_ejercicio_002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
# <img src="https://www.python.org/static/community_logos/python-powered-h-70x91.png">
# </p>

# %% [markdown]
# # ☯ <font color="DeepPink">**Actividad 002**</font>

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Habilitando Pandas**</font>

# %%
# mi código aquí
import pandas as pd
import numpy as np

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Datos**</font>

# %%
datos =  pd.read_csv("https://raw.githubusercontent.com/cristiandarioortegayubro/base/main/dataset/departamento.csv")

# %%
datos.shape
# Out:
# (2232, 8)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2232 entries, 0 to 2231
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   M2          2232 non-null   int64
#  1   AMBIENTES   2232 non-null   int64
#  2   ANTIGUEDAD  2232 non-null   int64
#  3   BAÑOS       2232 non-null   int64
#  4   LATITUD     2232 non-null   float64
#  5   LONGITUD    2232 non-null   float64
#  6   COMUNA      2232 non-null   object
#  7   DOLARES     2232 non-null   int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 139.6+ KB

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Creación del DataFrame**</font>

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Generar el dataframe**
# </font>
# </p>

# %%
dtype(datos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-483d05daf21d> in <cell line: 1>()
# ----> 1 dtype(datos)
#
# NameError: name 'dtype' is not defined

# %%
datos.index
# Out:
# RangeIndex(start=0, stop=2232, step=1)

# %% [markdown]
# ## 🔹 <font color="DeepPink">**A divertirse... 😃**</font>

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Visualizar solamente la columna (serie) dolares... y creamos esa serie...**
# </font>
# </p>

# %%
datos.iloc[:,7]
# Out:
# 0       225000
# 1       140000
# 2       154000
# 3        75000
# 4       149900
#          ...
# 2227    165000
# 2228     79900
# 2229    520000
# 2230    132000
# 2231    179000
# Name: DOLARES, Length: 2232, dtype: int64

# %%
datos["DOLARES"]
# Out:
# 0       225000
# 1       140000
# 2       154000
# 3        75000
# 4       149900
#          ...
# 2227    165000
# 2228     79900
# 2229    520000
# 2230    132000
# 2231    179000
# Name: DOLARES, Length: 2232, dtype: int64

# %%
VALOR_DEPTO = datos["DOLARES"]

# %%
VALOR_DEPTO
# Out:
# 0       225000
# 1       140000
# 2       154000
# 3        75000
# 4       149900
#          ...
# 2227    165000
# 2228     79900
# 2229    520000
# 2230    132000
# 2231    179000
# Name: DOLARES, Length: 2232, dtype: int64

# %%
VALOR_DEPTO.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2232 entries, 0 to 2231
# Series name: DOLARES
# Non-Null Count  Dtype
# --------------  -----
# 2232 non-null   int64
# dtypes: int64(1)
# memory usage: 17.6 KB

# %%
type(VALOR_DEPTO)
# Out:
# pandas.core.series.Series

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Buscamos pasar la serie anterior a dataframe...usando el metodo ```to.frame()```**
# </font>
# </p>

# %%
df = VALOR_DEPTO.to_frame()

# %%
df
# Out:
#       DOLARES
# 0      225000
# 1      140000
# 2      154000
# 3       75000
# 4      149900
# ...       ...
# 2227   165000
# 2228    79900
# 2229   520000
# 2230   132000
# 2231   179000
#
# [2232 rows x 1 columns]

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Mostrar en pantalla ```print()``` los $m^2$ de los departamentos...**
# </font>
# </p>

# %%
print(datos["M2"])
# Out:
# 0        81
# 1        69
# 2        75
# 3        42
# 4        90
#        ...
# 2227     88
# 2228     35
# 2229    117
# 2230     69
# 2231     73
# Name: M2, Length: 2232, dtype: int64

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Crear una nueva columna llamada PAIS y rellenarla con "Argentina"...**
# </font>
# </p>

# %%
pais = ["Argentina"]*2232

# %%
len(pais)
# Out:
# 2232

# %%
type(pais)
# Out:
# list

# %%
datos["PAIS"]=pais

# %%
datos
# Out:
#        M2  AMBIENTES  ANTIGUEDAD  BAÑOS    LATITUD   LONGITUD     COMUNA  \
# 0      81          3           4      1 -34.581078 -58.449433  COMUNA 13
# 1      69          3          20      1 -34.623129 -58.439338  COMUNA 06
# 2      75          3          20      1 -34.604972 -58.421278  COMUNA 05
# 3      42          2          40      1 -34.604725 -58.399524  COMUNA 03
# 4      90          3           1      1 -34.623390 -58.504401  COMUNA 10
# ...   ...        ...         ...    ...        ...        ...        ...
# 2227   88          4          20      2 -34.550152 -58.470136  COMUNA 13
# 2228   35          1          35      1 -34.602256 -58.429315  COMUNA 05
# 2229  117          3          10      2 -34.620314 -58.365451  COMUNA 01
# 2230   69          4          40      1 -34.628533 -58.427748  COMUNA 07
# 2231   73          4          50      2 -34.596659 -58.378396  COMUNA 01
#
#       DOLARES       PAIS
# 0      225000  Argentina
# 1      140000  Argentina
# 2      154000  Argentina
# 3       75000  Argentina
# 4      149900  Argentina
# ...       ...        ...
# 2227   165000  Argentina
# 2228    79900  Argentina
# 2229   520000  Argentina
# 2230   132000  Argentina
# 2231   179000  Argentina
#
# [2232 rows x 9 columns]

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Ahora una nueva columna llamada CONTINENTE y rellenarla con "America"...**
# </font>
# </p>

# %%
cont = ["America"]*2232

# %%
datos["CONTINENTE"]=cont

# %%
datos
# Out:
#        M2  AMBIENTES  ANTIGUEDAD  BAÑOS    LATITUD   LONGITUD     COMUNA  \
# 0      81          3           4      1 -34.581078 -58.449433  COMUNA 13
# 1      69          3          20      1 -34.623129 -58.439338  COMUNA 06
# 2      75          3          20      1 -34.604972 -58.421278  COMUNA 05
# 3      42          2          40      1 -34.604725 -58.399524  COMUNA 03
# 4      90          3           1      1 -34.623390 -58.504401  COMUNA 10
# ...   ...        ...         ...    ...        ...        ...        ...
# 2227   88          4          20      2 -34.550152 -58.470136  COMUNA 13
# 2228   35          1          35      1 -34.602256 -58.429315  COMUNA 05
# 2229  117          3          10      2 -34.620314 -58.365451  COMUNA 01
# 2230   69          4          40      1 -34.628533 -58.427748  COMUNA 07
# 2231   73          4          50      2 -34.596659 -58.378396  COMUNA 01
#
#       DOLARES       PAIS CONTINENTE
# 0      225000  Argentina    America
# 1      140000  Argentina    America
# 2      154000  Argentina    America
# 3       75000  Argentina    America
# 4      149900  Argentina    America
# ...       ...        ...        ...
# 2227   165000  Argentina    America
# 2228    79900  Argentina    America
# 2229   520000  Argentina    America
# 2230   132000  Argentina    America
# 2231   179000  Argentina    America
#
# [2232 rows x 10 columns]

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Generar una columna que se llame PESOS cuyo valor sea DOLARES $\times$ $300$...**
# </font>
# </p>

# %%
pesos = [0] * 2232

# %%
datos["PESOS"] = pesos
datos["PESOS"] = datos["DOLARES"]*300

# %%
datos
# Out:
#        M2  AMBIENTES  ANTIGUEDAD  BAÑOS    LATITUD   LONGITUD     COMUNA  \
# 0      81          3           4      1 -34.581078 -58.449433  COMUNA 13
# 1      69          3          20      1 -34.623129 -58.439338  COMUNA 06
# 2      75          3          20      1 -34.604972 -58.421278  COMUNA 05
# 3      42          2          40      1 -34.604725 -58.399524  COMUNA 03
# 4      90          3           1      1 -34.623390 -58.504401  COMUNA 10
# ...   ...        ...         ...    ...        ...        ...        ...
# 2227   88          4          20      2 -34.550152 -58.470136  COMUNA 13
# 2228   35          1          35      1 -34.602256 -58.429315  COMUNA 05
# 2229  117          3          10      2 -34.620314 -58.365451  COMUNA 01
# 2230   69          4          40      1 -34.628533 -58.427748  COMUNA 07
# 2231   73          4          50      2 -34.596659 -58.378396  COMUNA 01
#
#       DOLARES       PAIS CONTINENTE      PESOS
# 0      225000  Argentina    America   67500000
# 1      140000  Argentina    America   42000000
# 2      154000  Argentina    America   46200000
# 3       75000  Argentina    America   22500000
# 4      149900  Argentina    America   44970000
# ...       ...        ...        ...        ...
# 2227   165000  Argentina    America   49500000
# 2228    79900  Argentina    America   23970000
# 2229   520000  Argentina    America  156000000
# 2230   132000  Argentina    America   39600000
# 2231   179000  Argentina    America   53700000
#
# [2232 rows x 11 columns]

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Mostrar el resumen estadistico descriptivo del dataframe...**
# </font>
# </p>

# %%
datos.describe().round(2).T
# Out:
#              count         mean          std         min          25%  \
# M2          2232.0        79.40        58.98       15.00        44.00
# AMBIENTES   2232.0         2.81         1.11        1.00         2.00
# ANTIGUEDAD  2232.0        24.63        18.41        1.00         9.00
# BAÑOS       2232.0         1.43         0.72        1.00         1.00
# LATITUD     2232.0       -34.59         0.02      -34.68       -34.61
# LONGITUD    2232.0       -58.43         0.03      -58.53       -58.45
# DOLARES     2232.0    206014.01    186368.30     7428.00     98375.00
# PESOS       2232.0  61804203.63  55910491.15  2228400.00  29512500.00
#
#                     50%          75%           max
# M2                64.00        90.00  7.300000e+02
# AMBIENTES          3.00         3.00  1.000000e+01
# ANTIGUEDAD        20.00        40.00  1.100000e+02
# BAÑOS              1.00         2.00  6.000000e+00
# LATITUD          -34.59       -34.58 -3.454000e+01
# LONGITUD         -58.42       -58.40 -5.835000e+01
# DOLARES       146000.00    235750.00  1.800000e+06
# PESOS       43800000.00  70725000.00  5.400000e+08

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **¿Cual es la media de latitud y longitud?...**
# </font>
# </p>

# %%
# mi código aquí

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Un poco más dificil... 😈**</font>

# %% [markdown]
# ---
# <p>
# <font color="DeepPink">
#
# 👀 **Para los siguientes puntos se puede consultar la documentación técnica de Pandas...**
# </font>
# </p>
#
# ---

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Verificar si existen datos nulos en el dataframe...**
# </font>
# </p>

# %%
datos.isna().any()
# Out:
# M2            False
# AMBIENTES     False
# ANTIGUEDAD    False
# BAÑOS         False
# LATITUD       False
# LONGITUD      False
# COMUNA        False
# DOLARES       False
# PAIS          False
# CONTINENTE    False
# PESOS         False
# dtype: bool

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **¿Cuantos departamentos hay por comuna?...**
# </font>
# </p>

# %%
# mi código aquí

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **¿Cuantos ambientes tiene los departamentos de la comuna 14?...**
# </font>
# </p>

# %%
# mi código aquí

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# 💗
# <font color="DeepPink">
# Hemos llegado al final de nuestro colab, a seguir codeando...
# </font>
